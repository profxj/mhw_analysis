# %%
import xarray
import numpy as np
import seabo

# %%
chl=xarray.open_dataset("chl_2013-7.nc")
chl1=chl.chl
chl2=chl1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
chl3=chl2.sel(time='2013-7-15')
chl4=np.log(*chl3)
chl4.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[196])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)

# %%
c=((chl3-bls2)/(bls2))
c.plot()

# %%
chl=xarray.open_dataset("chl_2013-9.nc")
chl1=chl.chl
chl2=chl1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
chl3=chl2.sel(time='2013-9-15')
chl4=np.log(*chl3)
chl4.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[258])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
chl=xarray.open_dataset("chl_2015-6.nc")
chl1=chl.chl
chl2=chl1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
chl3=chl2.sel(time='2015-6-13')
chl4=np.log(*chl3)
chl4.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[164])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[164])

bls2=np.log(*bls1)
bls2.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)

# %%
mask=xarray.open_dataset('MHWS_2019_mask.nc',engine='h5netcdf')
m1=mask.sel(time=['2015-7-13'])
m2=m1.mask
m2.plot(vmax=600)

# %%
chl=xarray.open_dataset("chl_2015-7.nc")
chl1=chl.chl
chl2=chl1.sel(latitude=slice(-20, 60),longitude=slice(-180,-100))
chl3=chl2.sel(time='2015-7-13')
chl4=np.log(*chl3)
chl4.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[194])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
h=((chl3-bls2)/(bls2))
h.plot.hist()
# Out:
# (array([1.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+00, 3.7305e+04,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([-8995.688  , -6827.146  , -4658.6035 , -2490.061  ,  -321.51855,
#          1847.0239 ,  4015.5664 ,  6184.109  ,  8352.651  , 10521.193  ,
#         12689.736  ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
chl=xarray.open_dataset("chl_2016-9.nc")
chl1=chl.chl
chl2=chl1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
chl3=chl2.sel(time='2016-9-15')
chl4=np.log(*chl3)
chl4.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[258])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
chl=xarray.open_dataset("chl_2016-11.nc")
chl1=chl.chl
chl2=chl1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
chl3=chl2.sel(time='2016-11-15')
chl4=np.log(*chl3)
chl4.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[319])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
chl=xarray.open_dataset("chl_2016-12.nc")
chl1=chl.chl
chl2=chl1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
chl3=chl2.sel(time='2016-12-31')
chl4=np.log(*chl3)
chl4.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[365])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
mask=xarray.open_dataset('MHWS_2019_mask.nc',engine='h5netcdf')
m1=mask.sel(time=['2015-7-13'])
m2=m1.sel(lat=slice(-20, 60),lon=slice(150,300))
m3=m2.mask
m3.plot(vmax=600)

# %%
np.unique(m3)

# %%
mask=xarray.open_dataset('MHWS_2019_mask.nc',engine='h5netcdf')
m1=mask.sel(time=['2013-7-15'])
m2=m1.sel(lat=slice(20, 60),lon=slice(175,255))
m3=m2.mask
m3.plot()

# %%
mask=xarray.open_dataset('MHWS_2019_mask.nc',engine='h5netcdf')
m1=mask.sel(time=['2013-9-15'])
m2=m1.sel(lat=slice(20, 60),lon=slice(175,255))
m3=m2.mask
m3.plot()

# %%
mask=xarray.open_dataset('MHWS_2019_mask.nc',engine='h5netcdf')
m1=mask.sel(time=['2015-6-13'])
m2=m1.sel(lat=slice(20, 60),lon=slice(175,255))
m3=m2.mask
m3.plot()

# %%
mask=xarray.open_dataset('MHWS_2019_mask.nc',engine='h5netcdf')
m1=mask.sel(time=['2016-9-15'])
m2=m1.sel(lat=slice(20, 60),lon=slice(175,255))
m3=m2.mask
m3.plot()

# %%
mask=xarray.open_dataset('MHWS_2019_mask.nc',engine='h5netcdf')
m1=mask.sel(time=['2016-11-15'])
m2=m1.sel(lat=slice(20, 60),lon=slice(175,255))
m3=m2.mask
m3.plot()

# %%
mask=xarray.open_dataset('MHWS_2019_mask.nc',engine='h5netcdf')
#m1=mask.sel(time=['2016-12-31'])
#m1.mask[land] = np.nan
m2=m1.sel(lat=slice(20, 60),lon=slice(175,255))
m3=m2.mask
m3.plot()

# %%
m1.mask.data[:,:,0][land[0,:,:]] = -99999

# %%
m1.mask.shape
# Out:
# (720, 1440, 1)

# %%
land.shape
# Out:
# (1, 720, 1440)

# %%
sst=xarray.open_dataset("sst.day.mean.2013.nc")
sst1=sst.sel(time=['2013-7-15'])
sst2=sst1.sel(lat=slice(20, 60),lon=slice(175,255))
sst3=sst2.sst
sst3.plot()

# %%
sst1
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, lat: 720, lon: 1440)
# Coordinates:
#   * time     (time) datetime64[ns] 2013-07-15
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
# Data variables:
#     sst      (time, lat, lon) float32 ...
# Attributes:
#     Conventions:    CF-1.5
#     title:          NOAA High-resolution Blended Analysis: Daily Values using...
#     institution:    NOAA/NCDC
#     source:         NOAA/NCDC  ftp://eclipse.ncdc.noaa.gov/pub/OI-daily-v2/
#     comment:        Reynolds, et al., 2007: Daily High-Resolution-Blended Ana...
#     history:        Thu Aug 24 13:51:22 2017: ncatted -O -a References,global...
#     dataset_title:  NOAA Daily Optimum Interpolation Sea Surface Temperature
#     References:     https://www.psl.noaa.gov/data/gridded/data.noaa.oisst.v2....

# %%
land = np.isnan(sst1.sst.data)

# %%
sst=xarray.open_dataset("sst.day.mean.2013.nc")
sst1=sst.sel(time=['2013-9-15'])
sst2=sst1.sel(lat=slice(20, 60),lon=slice(175,255))
sst3=sst2.sst
sst3.plot()

# %%
sst=xarray.open_dataset("sst.day.mean.2015.nc")
sst1=sst.sel(time=['2015-6-13'])
sst2=sst1.sel(lat=slice(20, 60),lon=slice(175,255))
sst3=sst2.sst
sst3.plot()

# %%
sst=xarray.open_dataset("sst.day.mean.2015.nc")
sst1=sst.sel(time=['2015-7-13'])
sst2=sst1.sel(lat=slice(20, 60),lon=slice(175,255))
sst3=sst2.sst
sst3.plot()

# %%
sst=xarray.open_dataset("sst.day.mean.2016.nc")
sst1=sst.sel(time=['2016-9-15'])
sst2=sst1.sel(lat=slice(20, 60),lon=slice(175,255))
sst3=sst2.sst
sst3.plot()

# %%
sst=xarray.open_dataset("sst.day.mean.2016.nc")
sst1=sst.sel(time=['2016-11-15'])
sst2=sst1.sel(lat=slice(20, 60),lon=slice(175,255))
sst3=sst2.sst
sst3.plot()

# %%
sst=xarray.open_dataset("sst.day.mean.2016.nc")
sst1=sst.sel(time=['2016-12-31'])
sst2=sst1.sel(lat=slice(20, 60),lon=slice(175,255))
sst3=sst2.sst
sst3.plot()

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[196])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[258])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[164])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[194])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[258])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[319])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)

# %%
bl=xarray.open_dataset("CHL_baseline_1993-2020.nc")
bls=bl.seasonalT
bls1=bls.sel(doy=[365])
bls2=bls1.sel(latitude=slice(20, 60),longitude=slice(-180,-100))
bls3=np.log(*bls2)
bls3.plot(vmax=5)
