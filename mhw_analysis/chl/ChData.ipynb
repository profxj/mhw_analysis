# %%
import xarray
import numpy as np

# %%
chw=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647983609130.nc")
chw1=chw.CHL
chw2=np.log(*chw1)
chw2.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
chw3=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647983964206.nc")
chw4=chw3.CHL
chw5=np.log(*chw4)
chw5.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
bl=chw5-chw2

# %%
bl
# Out:
# <xarray.DataArray 'CHL' (lat: 4320, lon: 8640)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 89.98 89.94 89.9 89.85 ... -89.85 -89.9 -89.94 -89.98
#   * lon      (lon) float32 -180.0 -179.9 -179.9 -179.9 ... 179.9 179.9 180.0

# %%
bl.plot()

# %%
ch=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647975799837.nc")

# %%
ch
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, lat: 1441, lon: 2160)
# Coordinates:
#   * time     (time) datetime64[ns] 2015-06-15
#   * lat      (lat) float32 60.02 59.98 59.94 59.9 ... 0.1042 0.0625 0.02083
#   * lon      (lon) float32 -180.0 -179.9 -179.9 -179.9 ... -90.1 -90.06 -90.02
# Data variables:
#     CHL      (time, lat, lon) float32 ...
# Attributes: (12/65)
#     comment:                      average
#     distribution_statement:       See CMEMS Data License
#     site_name:                    GLO
#     parameter_code:               CHL
#     creation_time:                02:56:45 UTC
#     creation_date:                2021-10-28 UTC
#     ...                           ...
#     parameter:                    Chlorophyll-a concentration
#     History:                      Translated to CF-1.0 Conventions by Netcdf-...
#     geospatial_lat_min:           0.020830651745200157
#     geospatial_lat_max:           60.02083206176758
# ...

# %%
chl=ch.CHL

# %%
chl.plot(vmax=5)

# %%
c6=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647976855265.nc")
c61=c6.CHL
x=[]

# %%
cn = np.array([c61 - chl[i] for i in range(len(chl))])

# %%
cn
# Out:
# array([[[[-0.13223612, -0.11553276, -0.15186185, ..., -0.42428014,
#           -0.42240804, -0.41718864],
#          [-0.0524869 , -0.12442291, -0.00350946, ..., -0.43742323,
#           -0.45042643, -0.4623637 ],
#          [-0.19916928, -0.16951293, -0.05109203, ..., -0.42012227,
#           -0.39821345, -0.41855708],
#          ...,
#          [ 0.032393  ,  0.02798291,  0.01065991, ...,  0.12788661,
#            0.12377898,  0.11114104],
#          [ 0.03622914,  0.04598584,  0.02092965, ...,  0.12870042,
#            0.13205786,  0.12248181],
#          [ 0.03419407,  0.12311511,  0.02696715, ...,  0.11346857,
#            0.13122706,  0.13243034]]]], dtype=float32)

# %%
#mshow or pcolormesh

# %%
c61
# Out:
# <xarray.DataArray 'CHL' (time: 1, lat: 1441, lon: 2160)>
# [3112560 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2009-06-15
#   * lat      (lat) float32 60.02 59.98 59.94 59.9 ... 0.1042 0.0625 0.02083
#   * lon      (lon) float32 -180.0 -179.9 -179.9 -179.9 ... -90.1 -90.06 -90.02
# Attributes:
#     input_files_reprocessings:  Processors versions: MODIS 2018.1/VIIRSN 2018...
#     long_name:                  Chlorophyll-a concentration - Mean of the bin...
#     valid_min:                  0.0
#     valid_max:                  1000.0
#     standard_name:              mass_concentration_of_chlorophyll_a_in_sea_water
#     units:                      milligram m-3
#     type:                       surface
#     _ChunkSizes:                [  1 256 256]

# %%
chl
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, lat: 961, lon: 1920)
# Coordinates:
#   * time     (time) datetime64[ns] 2013-09-15
#   * lat      (lat) float32 60.02 59.98 59.94 59.9 ... 20.15 20.1 20.06 20.02
#   * lon      (lon) float32 -180.0 -179.9 -179.9 -179.9 ... -100.1 -100.1 -100.0
# Data variables:
#     CHL      (time, lat, lon) float32 ...
# Attributes: (12/65)
#     comment:                      average
#     distribution_statement:       See CMEMS Data License
#     site_name:                    GLO
#     parameter_code:               CHL
#     creation_time:                02:56:45 UTC
#     creation_date:                2021-10-28 UTC
#     ...                           ...
#     parameter:                    Chlorophyll-a concentration
#     History:                      Translated to CF-1.0 Conventions by Netcdf-...
#     geospatial_lat_min:           20.020832061767578
#     geospatial_lat_max:           60.02083206176758
# ...

# %%
ch2=np.log(*chl)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
ch2.plot(vmax=10)

# %%
b=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646767971699.nc")
b1=b.CHL
b1.plot(vmax=5)

# %%
chw=np.log(*b1)
chw.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
chl=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646761712633.nc")

# %%
chl
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, lat: 961, lon: 1920)
# Coordinates:
#   * time     (time) datetime64[ns] 2013-09-15
#   * lat      (lat) float32 60.02 59.98 59.94 59.9 ... 20.15 20.1 20.06 20.02
#   * lon      (lon) float32 -180.0 -179.9 -179.9 -179.9 ... -100.1 -100.1 -100.0
# Data variables:
#     CHL      (time, lat, lon) float32 ...
# Attributes: (12/65)
#     comment:                      average
#     distribution_statement:       See CMEMS Data License
#     site_name:                    GLO
#     parameter_code:               CHL
#     creation_time:                02:56:45 UTC
#     creation_date:                2021-10-28 UTC
#     ...                           ...
#     parameter:                    Chlorophyll-a concentration
#     History:                      Translated to CF-1.0 Conventions by Netcdf-...
#     geospatial_lat_min:           20.020832061767578
#     geospatial_lat_max:           60.02083206176758
# ...

# %%
chl1=chl.CHL

# %%
chl1.plot(vmax=5)

# %%
ch3=np.log(*chl1)
ch3.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
chl2=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646761822289.nc")

# %%
chl3=chl2.CHL
chl3.plot(vmax=5)

# %%
ch4=np.log(*chl3)
ch4.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
z=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646766536992.nc")
z1=z.CHL
z1.plot(vmax=5)

# %%
z2=np.log(*z1)
z2.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
chl4=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646761882993.nc")
chl5=chl4.CHL
chl5.plot(vmax=5)

# %%
ch5=np.log(*chl5)
ch5.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
chl6=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646762099241.nc")
chl7=chl6.CHL
chl7.plot(vmax=5)

# %%
ch6=np.log(*chl7)
ch6.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
chl8=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646762133967.nc")
chl9=chl8.CHL
chl9.plot(vmax=5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     198 try:
# --> 199     file = self._cache[self._key]
#     200 except KeyError:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/backends/lru_cache.py:53, in LRUCache.__getitem__(self, key)
#      52 with self._lock:
# ---> 53     value = self._cache[key]
#      54     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Users/SierraSakrison/sst/mhw_analysis/mhw_analysis/chl/dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646762133967.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# ...

# %%
ch7=np.log(*chl9)
ch7.plot(vmax=5)

# %%
chl10=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646762164029.nc")
chl11=chl10.CHL
chl11.plot(vmax=5)

# %%
ch8=np.log(*chl11)
ch8.plot(vmax=5)

# %%
chl12=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646762190967.nc")
chl13=chl12.CHL
chl13.plot(vmax=5)

# %%
ch9=np.log(*chl13)
ch9.plot(vmax=5)

# %%
chl14=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1646762231799.nc")
chl15=chl14.CHL
chl15.plot(vmax=5)

# %%
ch10=np.log(*chl15)
ch10.plot(vmax=5)

# %%
ch4

# %%
chl5=ch4.chl

# %%
chl5.plot()

# %%
ch4.chl.max()

# %%
ch4.chl.min()

# %%
wa=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647978103501.nc")
wa1=wa.CHL
wa2=np.log(*wa1)
wa2.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
wa3=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647978057547.nc")
wa4=wa3.CHL
wa5=np.log(*wa4)
wa5.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
wa6=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647978180020.nc")
wa7=wa6.CHL
wa8=np.log(*wa7)
wa8.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
wa9=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647978238917.nc")
wa10=wa9.CHL
wa11=np.log(*wa10)
wa11.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
wa12=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647978369340.nc")
wa13=wa12.CHL
wa14=np.log(*wa13)
wa14.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
wa15=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647978438362.nc")
wa16=wa15.CHL
wa17=np.log(*wa16)
wa17.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
wa18=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647978639965.nc")
wa19=wa18.CHL
wa20=np.log(*wa19)
wa20.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)

# %%
wa21=xarray.open_dataset("dataset-oc-glo-bio-multi-l4-chl_interpolated_4km_daily-rep_1647978691084.nc")
wa22=wa21.CHL
wa23=np.log(*wa22)
wa23.plot(vmax=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xarray/core/computation.py:733: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
