# %% [markdown]
# # Testing Full

# %%
# imports
import numpy as np
import pandas
import sqlalchemy

# %% [markdown]
# # Init

# %%
engine = sqlalchemy.create_engine('sqlite:////home/xavier/Projects/Oceanography/MHWs/db/test_mhws_allsky.db')

# %%
full_tbl = pandas.read_sql_table('MHW_Events', con=engine)#, columns=['lat', 'lon'])

# %%
full_tbl
# Out:
#       index  time_start  time_end  time_peak  duration  duration_moderate  \
# 0         0      723546    723558     723552        13                  1
# 1         1      723899    723931     723901        33                 14
# 2         2      724671    724680     724677        10                 10
# 3         3      725746    725754     725752         9                  9
# 4         4      726841    726892     726858        52                 52
# ...     ...         ...       ...        ...       ...                ...
# 1235     73      736022    736043     736027        22                 22
# 1236     74      736142    736159     736152        18                 18
# 1237     75      736236    736246     736240        11                 11
# 1238     76      736309    736318     736310        10                 10
# 1239     77      736324    736329     736329         6                  6
#
#       duration_strong  duration_severe  duration_extreme  category  ...  \
# ...

# %%
np.unique(full_tbl['lon'])
# Out:
# array([0.125, 0.375])

# %% [markdown]
# ----
