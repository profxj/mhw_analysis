# %% [markdown]
# # Climate

# %%
# imports
from matplotlib import pyplot as plt

import iris
from iris import quickplot

# %%
# %matplotlib notebook

# %% [markdown]
# # Load

# %%
test_climate_file = '/home/xavier/Projects/Oceanography/MHWs/db/test_climate.nc'
climate_file = '/home/xavier/Projects/Oceanography/MHWs/db/full_climate.nc'

# %%
#cube = iris.load(test_climate_file)
cube = iris.load(climate_file)

# %%
cube
# Out:
# [<iris 'Cube' of seasonalT / (C) (day: 366; latitude: 720; longitude: 1440)>,
# <iris 'Cube' of threshT / (C) (day: 366; latitude: 720; longitude: 1440)>]

# %% [markdown]
# ## Parse

# %%
seasonal = cube[0]
seasonal
# Out:
# <iris 'Cube' of seasonalT / (C) (day: 366; latitude: 720; longitude: 1440)>

# %% [markdown]
# ## Plot

# %%
time = iris.Constraint(day=0)

# %%
jan1 = seasonal.extract(time)

# %%
jan1
# Out:
# <iris 'Cube' of seasonalT / (C) (latitude: 720; longitude: 1440)>

# %%
# Draw the contour with 25 levels.
quickplot.contourf(jan1, 25)

# Add coastlines to the map created by contourf.
plt.gca().coastlines()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="945">
