# %% [markdown]
# # MHW Systems

# %%
#imports
from importlib import reload

import numpy as np
import os
from matplotlib import pyplot as plt

from mhw_analysis.systems import build

# %%
# %matplotlib notebook

# %% [markdown]
# # Load (this cube was built by MWH_3D)

# %%
#cube = np.load('tst_cube.npy')
cube = np.load('tst_cube_pacific.npy')
cube.shape
# Out:
# (278, 81, 81)

# %% [markdown]
# # Explore

# %%
ch = 80
plt.clf()
plt.imshow(cube[ch, :, :])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# # Build one

# %% [markdown]
# ## Convert cube to bool

# %%
cube = cube.astype(bool)

# %% [markdown]
# ## Run it

# %%
reload(build)
mask, parent = build.make_labels(cube)
# Out:
# NObj Extracted= 174
# Nobj Detected = 174

# %%
np.max(mask)
# Out:
# 1431

# %%
for ii in range(1,np.max(mask)):
    print(ii,np.sum(mask==ii))
# Out:
# 1 16
# 2 969191
# 3 19
# 4 5483
# 5 182842
# 6 15
# 7 10302
# 8 1
# 9 527
# 10 49332
# 11 3
# 12 10
# 13 25409
# 14 38
# 15 148
# 16 35
# 17 6
# 18 115
# 19 16594
# 20 171
# 21 7
# 22 5
# 23 720
# 24 18
# 25 1500
# 26 471
# 27 1
# 28 8
# 29 1
# 30 124
# 31 12
# 32 1
# 33 94
# 34 44
# 35 52545
# 36 4
# 37 21
# 38 6
# 39 11
# 40 2145
# 41 6
# 42 6
# 43 21
# 44 58
# 45 9
# 46 3
# 47 65
# 48 7
# 49 473
# 50 175
# 51 7
# 52 7
# 53 3
# 54 2
# 55 668
# 56 13
# 57 63
# 58 235
# 59 1
# 60 23
# 61 333
# 62 599
# 63 123
# 64 361
# 65 64
# 66 733
# 67 45
# 68 1
# 69 2
# 70 46
# 71 7
# 72 61
# 73 33
# 74 161
# 75 31
# 76 2
# 77 18
# 78 55
# 79 28
# 80 8020
# 81 40
# 82 18
# 83 1
# 84 11
# 85 24
# 86 913
# 87 32534
# 88 18
# 89 1
# 90 6
# 91 8628
# 92 205
# 93 6
# 94 6
# 95 4
# 96 18
# 97 259
# 98 127
# 99 12
# 100 1825
# 101 20
# 102 1423
# 103 1574
# 104 4898
# 105 109
# 106 1
# 107 102
# 108 7
# 109 3
# 110 44
# 111 258
# 112 36
# 113 2
# 114 1
# 115 6
# 116 6
# 117 12
# 118 1
# 119 9
# 120 2
# ...

# %%
cube.size
# Out:
# 2840913

# %%
#
