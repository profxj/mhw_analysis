# %% [markdown]
# # Check the Days by Year algorithm

# %%
# imports
import os
import numpy as np

import xarray

# %% [markdown]
# # Load up

# %%
path = '/tank/xavier/Oceanography/MHW/db'
#ds = xarray.open_dataset(os.path.join(path, 'extreme_dy_by_yr_defaults.nc'))
ds = xarray.open_dataset('extreme_dy_by_yr_defaults.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, year: 38)
# Coordinates:
#   * lat      (lat) float32 -89.875 -89.625 -89.375 ... 89.375 89.625 89.875
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.375 359.625 359.875
#   * year     (year) int64 1982 1983 1984 1985 1986 ... 2015 2016 2017 2018 2019
# Data variables:
#     ndays    (lat, lon, year) int32 ...

# %% [markdown]
# # Plot

# %%
y1983 = ds.ndays[:,:,1]

# %%
y1983
# Out:
# <xarray.DataArray 'ndays' (lat: 720, lon: 1440)>
# [1036800 values with dtype=int32]
# Coordinates:
#   * lat      (lat) float32 -89.875 -89.625 -89.375 ... 89.375 89.625 89.875
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.375 359.625 359.875
#     year     int64 1983

# %%
y1983.plot()

# %%
y1983.data.sum()
# Out:
# 13059493
